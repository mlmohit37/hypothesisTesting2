# %%
import pandas as pd
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
from matplotlib import pyplot
import pylab as py

import warnings 
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('apollo_hospitals.csv')
df
# Out:
#       Unnamed: 0  age     sex smoker     region  viral load  severity level  \
# 0              0   19  female    yes  southwest        9.30               0
# 1              1   18    male     no  southeast       11.26               1
# 2              2   28    male     no  southeast       11.00               3
# 3              3   33    male     no  northwest        7.57               0
# 4              4   32    male     no  northwest        9.63               0
# ...          ...  ...     ...    ...        ...         ...             ...
# 1333        1333   50    male     no  northwest       10.32               3
# 1334        1334   18  female     no  northeast       10.64               0
# 1335        1335   18  female     no  southeast       12.28               0
# 1336        1336   21  female     no  southwest        8.60               0
# 1337        1337   61  female    yes  northwest        9.69               0
#
#       hospitalization charges
# 0                       42212
# 1                        4314
# 2                       11124
# 3                       54961
# 4                        9667
# ...                       ...
# 1333                    26501
# 1334                     5515
# 1335                     4075
# 1336                     5020
# 1337                    72853
#
# [1338 rows x 8 columns]

# %% [markdown]
# ## 1. Define Problem Statement and perform Exploratory Data Analysis
#
# **1.a. Definition of problem (as per given problem statement with additional views).**\
# => Which variables are significant in predicting the reason for hospitalization for different regions.\
# => How well some variables like viral load, smoking, Severity Level describe the hospitalization charges.\
# => Check if there is any relation between age and hospital charges.\
# **1.b. Observations on shape of data, data types of all the attributes, conversion of categorical attributes to 'category' (If required) , missing value detection, statistical summary.**

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'age', 'sex', 'smoker', 'region', 'viral load',
#        'severity level', 'hospitalization charges'],
#       dtype='object')

# %%
# Let's remove 'Unnamed: 0' column as it is not useful.
df = df.drop('Unnamed: 0', axis=1)

# %%
df.head()
# Out:
#    age     sex smoker     region  viral load  severity level  \
# 0   19  female    yes  southwest        9.30               0
# 1   18    male     no  southeast       11.26               1
# 2   28    male     no  southeast       11.00               3
# 3   33    male     no  northwest        7.57               0
# 4   32    male     no  northwest        9.63               0
#
#    hospitalization charges
# 0                    42212
# 1                     4314
# 2                    11124
# 3                    54961
# 4                     9667

# %%
df.shape
# Out:
# (1338, 7)

# %%
df.columns
# Out:
# Index(['age', 'sex', 'smoker', 'region', 'viral load', 'severity level',
#        'hospitalization charges'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   age                      1338 non-null   int64
#  1   sex                      1338 non-null   object
#  2   smoker                   1338 non-null   object
#  3   region                   1338 non-null   object
#  4   viral load               1338 non-null   float64
#  5   severity level           1338 non-null   int64
#  6   hospitalization charges  1338 non-null   int64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 73.3+ KB

# %%
# conversion of categorical attributes to 'category'.

df['sex'] = df.sex.astype('category')
df['smoker'] = df.smoker.astype('category')
df['region'] = df.region.astype('category')
df['severity level'] = df['severity level'].astype('category')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   age                      1338 non-null   int64
#  1   sex                      1338 non-null   category
#  2   smoker                   1338 non-null   category
#  3   region                   1338 non-null   category
#  4   viral load               1338 non-null   float64
#  5   severity level           1338 non-null   category
#  6   hospitalization charges  1338 non-null   int64
# dtypes: category(4), float64(1), int64(2)
# memory usage: 37.4 KB

# %%
numerical_cols = ['age', 'viral load', 'hospitalization charges']
categorical_cols = ['sex', 'smoker', 'region', 'severity level']

# %%
df[numerical_cols].describe()
# Out:
#                age   viral load  hospitalization charges
# count  1338.000000  1338.000000              1338.000000
# mean     39.207025    10.221233             33176.058296
# std      14.049960     2.032796             30275.029296
# min      18.000000     5.320000              2805.000000
# 25%      27.000000     8.762500             11851.000000
# 50%      39.000000    10.130000             23455.000000
# 75%      51.000000    11.567500             41599.500000
# max      64.000000    17.710000            159426.000000

# %% [markdown]
# Inference: I do not think there will be outliers. But in 'hospitalization charges' column, there might be outliers.

# %%
df[categorical_cols].describe()
# Out:
#          sex smoker     region  severity level
# count   1338   1338       1338            1338
# unique     2      2          4               6
# top     male     no  southeast               0
# freq     676   1064        364             574

# %%
# Count the number of null values in each columns

df.isna().sum()
# Out:
# age                        0
# sex                        0
# smoker                     0
# region                     0
# viral load                 0
# severity level             0
# hospitalization charges    0
# dtype: int64

# %% [markdown]
# Inference: There are no missing values in the dataset.

# %%
df[numerical_cols].boxplot(rot=25, figsize=(25,8))
# Out:
# <AxesSubplot:>

# %% [markdown]
# **1.c. Missing values Treatment & Outlier treatment**

# %%
Q1 = df[numerical_cols].quantile(0.25)
Q3 = df[numerical_cols].quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# age                           24.000
# viral load                     2.805
# hospitalization charges    29748.500
# dtype: float64

# %%
df = df[~((df[numerical_cols] < (Q1 - 1.5 * IQR)) |(df[numerical_cols] > (Q3 + 1.5 * IQR))).any(axis=1)]
df = df.reset_index(drop=True)

# %%
df
# Out:
#       age     sex smoker     region  viral load severity level  \
# 0      19  female    yes  southwest        9.30              0
# 1      18    male     no  southeast       11.26              1
# 2      28    male     no  southeast       11.00              3
# 3      33    male     no  northwest        7.57              0
# 4      32    male     no  northwest        9.63              0
# ...   ...     ...    ...        ...         ...            ...
# 1188   50    male     no  northwest       10.32              3
# 1189   18  female     no  northeast       10.64              0
# 1190   18  female     no  southeast       12.28              0
# 1191   21  female     no  southwest        8.60              0
# 1192   61  female    yes  northwest        9.69              0
#
#       hospitalization charges
# 0                       42212
# 1                        4314
# 2                       11124
# 3                       54961
# 4                        9667
# ...                       ...
# 1188                    26501
# 1189                     5515
# 1190                     4075
# 1191                     5020
# 1192                    72853
#
# [1193 rows x 7 columns]

# %%
df[['age', 'viral load']].boxplot(rot=25, figsize=(25,8))
# Out:
# <AxesSubplot:>

# %%
df[numerical_cols].boxplot(rot=25, figsize=(25,8))
# Out:
# <AxesSubplot:>

# %% [markdown]
# **1.d. Univariate Analysis (distribution plots of all the continuous variable(s) barplots/countplots of all the categorical variables)**
#
# **Numerical Variables**

# %%
df["age"].hist(bins=50)
# Out:
# <AxesSubplot:>

# %%
sm.qqplot(df["age"], line ='s')
py.show()

# %% [markdown]
# Inference: Lot of patients are children from the age 10-20 years. And it is nowhere close to Normal distribution

# %%
df["viral load"].hist(bins=50)
# Out:
# <AxesSubplot:>

# %%
sm.qqplot(df["viral load"], line ='s')
py.show()

# %% [markdown]
# Inference: 'viral load' column is following Normal Distribution.

# %% [markdown]
# Inference: "severity level" column is not at all following Normal Distribution.

# %%
df["hospitalization charges"].hist(bins=50)
# Out:
# <AxesSubplot:>

# %%
sm.qqplot(df["hospitalization charges"], line ='s')
py.show()

# %% [markdown]
# Inference: "hospitalization charges" column is not following Normal Distribution.

# %% [markdown]
# **Categorical Columns**

# %%
sns.countplot(x="sex", data=df)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %% [markdown]
# Inference: There are equal number of male and female patients.

# %%
sns.countplot(x="smoker", data=df)
# Out:
# <AxesSubplot:xlabel='smoker', ylabel='count'>

# %% [markdown]
# Inference: Smokers are very very less than Non-smokers. Only 10% of the non-smokers are smokers.

# %%
sns.countplot(x="region", data=df)
# Out:
# <AxesSubplot:xlabel='region', ylabel='count'>

# %% [markdown]
# Inference: From all the regions of Delhi, there are same amount of patients.

# %%
sns.countplot(x="severity level", data=df)
# Out:
# <AxesSubplot:xlabel='severity level', ylabel='count'>

# %% [markdown]
# Inference: There are least number of high severity cases. As the severity increases, the number of patients belonging to that severity decreases.

# %% [markdown]
# **1.e. Bivariate Analysis (Relationships between important variables)**

# %%
sns.set(rc = {'figure.figsize':(10,10)})
sns.heatmap(df.corr(), cmap="YlGnBu", annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Inference: No two numerical variables are correlated to each other.

# %% [markdown]
# **viral load v/s severity level**

# %%
sns.boxplot(data = df, x = "severity level", y = "viral load")
# Out:
# <AxesSubplot:xlabel='severity level', ylabel='viral load'>

# %% [markdown]
# Inference: Viral load is not dependent of severity level. For all severity level, we have patients with viral load between 9 to 11.

# %% [markdown]
# **sex v/s smoker**

# %%
sns.histplot(binwidth=0.5, x="smoker", hue="sex", data=df, stat="count", multiple="stack")
# Out:
# <AxesSubplot:xlabel='smoker', ylabel='Count'>

# %% [markdown]
# Inference: Among smokers, 50% people are men and rest 50% people are women.

# %% [markdown]
# **age v/s viral load**

# %%
sns.scatterplot(data=df, x="age", y="viral load")
# Out:
# <AxesSubplot:xlabel='age', ylabel='viral load'>

# %% [markdown]
# Inference: Age and viral load are independent to each other. I do not find any relationship between age and viral load.

# %% [markdown]
# **age v/s severity level**

# %%
sns.boxplot(data = df, x = "severity level", y = "age")
# Out:
# <AxesSubplot:xlabel='severity level', ylabel='age'>

# %% [markdown]
# Inference: On an average people at age=40 have some severity.

# %% [markdown]
# **age v/s hospitalization charges**

# %%
sns.scatterplot(data=df, x="age", y="hospitalization charges")
# Out:
# <AxesSubplot:xlabel='age', ylabel='hospitalization charges'>

# %% [markdown]
# Inference: I can see some upward trend which tells that as the age increases, your hospital bills also increases.

# %% [markdown]
# **hospitalization charges v/s smoker**

# %%
sns.boxplot(data = df, x = "smoker", y = "hospitalization charges")
# Out:
# <AxesSubplot:xlabel='smoker', ylabel='hospitalization charges'>

# %% [markdown]
# Inference: It is clearly evident that people who smoke tend to spend more on hospitalization charges.

# %% [markdown]
# **hospitalization charges v/s severity level**

# %%
sns.boxplot(data = df, x = "severity level", y = "hospitalization charges")
# Out:
# <AxesSubplot:xlabel='severity level', ylabel='hospitalization charges'>

# %% [markdown]
# Inference: Even with 0 severity, you can have high hospitalization charges. As the severity increases, the hospitalization charges also increases. Since there are lesser number of severity-5 people, the trend has gone down from severity-4 people.

# %% [markdown]
# **hospitalization charges v/s viral load**

# %%
sns.scatterplot(data=df, x="viral load", y="hospitalization charges")
# Out:
# <AxesSubplot:xlabel='viral load', ylabel='hospitalization charges'>

# %% [markdown]
# Inference: There is no relationship between viral load and hospitalization charges.

# %% [markdown]
# **region v/s viral load**

# %%
sns.boxplot(data = df, x = "region", y = "viral load")
# Out:
# <AxesSubplot:xlabel='region', ylabel='viral load'>

# %% [markdown]
# Inference: We can observe that there is higher viral loads in southeast and southwest part of Delhi

# %% [markdown]
# **region v/s severity level**

# %%
sns.histplot(binwidth=0.5, x="severity level", hue="region", data=df, stat="count", multiple="stack")
# Out:
# <AxesSubplot:xlabel='severity level', ylabel='Count'>

# %% [markdown]
# Inference: There is almost same number of people from each region with particular severity.

# %% [markdown]
# **region v/s hospitalization charges**

# %%
sns.boxplot(data = df, x = "region", y = "hospitalization charges")
# Out:
# <AxesSubplot:xlabel='region', ylabel='hospitalization charges'>

# %% [markdown]
# Inference: For all the regions, hospital bills coming are almost same.

# %% [markdown]
# ## 2. Hypothesis Testing
#
# **2.a. Prove (or disprove) that the hospitalization charges of people who do smoking are greater than those who don't?**
#
# Let,\
# ho: hospitalization charges of people who do smoking <= hospitalization charges of people who donot do smoking.\
# ha: hospitalization charges of people who do smoking >= hospitalization charges of people who donot do smoking.\
#
# **T-test Right tailed**

# %%
# I am not sampling from the dataset because we just have around 1000 datapints.

# %%
df["smoker"].value_counts()
# Out:
# no     1055
# yes     138
# Name: smoker, dtype: int64

# %%
sns.distplot(df["hospitalization charges"], bins = 25)
# Out:
# <AxesSubplot:xlabel='hospitalization charges', ylabel='Density'>

# %% [markdown]
# Inference: It looks like Log-normal distribution.

# %%
# Checking whether the above distribution is a Log normal or not.
df["log_hospitalization_charges"] = np.log(df["hospitalization charges"])

# %%
sns.distplot(df["log_hospitalization_charges"], bins = 25)
# Out:
# <AxesSubplot:xlabel='log_hospitalization_charges', ylabel='Density'>

# %%
# Finding out the means for both the groups

df.groupby("smoker")["hospitalization charges"].mean()
# Out:
# smoker
# no     20907.971564
# yes    55035.586957
# Name: hospitalization charges, dtype: float64

# %% [markdown]
# Inference: Avg hospitalization charges of smokers is ~60% more than that of non-smokers.

# %%
# separating the data for treatment group and control group.

df_non_smokers = df[df["smoker"] == "no"]
df_smokers = df[df["smoker"] == "yes"]

# %%
df_smokers["hospitalization charges"].mean() - df_non_smokers["hospitalization charges"].mean()
# Out:
# 34127.6153925407

# %%
stats.ttest_ind( df_smokers["hospitalization charges"], df_non_smokers["hospitalization charges"], alternative="less")
# Out:
# Ttest_indResult(statistic=26.042742964009594, pvalue=1.0)

# %% [markdown]
# Here pvalue<0.05, that difference of ~Rs.29,000 is significant enough to say that there is a huge difference between hospitalization charges of non-smokers group and smokers group. So we will be rejecting our Null Hypothesis(ho) and accept Alternate Hypothesis(ha).
#
# Lets pick the t-critical values by the t-distribution table.\
# We are going with Two sample one-sided t-test.\
# From this table, since sample size is more than 1,000, z-stats for 0.05 Confidence is ~1.64.
# Therefore tcritical = 1.64.\
# And tstats = 26.04, which is greater than tcritical.\
# Therefore we reject the Null Hypothesis and go with Alternate Hypothesis.
#
# **Therefore, hospitalization charges of people who do smoking >= hospitalization charges of people who donot do smoking.**

# %% [markdown]
# **2.b. Prove (or disprove) with statistical evidence that the viral load of females is different from that of males**
#
# Let,\
# ho: viral load of females == viral load of males\
# ha: viral load of females != viral load of males\
#
# **T-test Two tailed**

# %%
df["sex"].value_counts()
# Out:
# female    611
# male      582
# Name: sex, dtype: int64

# %%
sns.distplot(df["viral load"], bins = 25)
# Out:
# <AxesSubplot:xlabel='viral load', ylabel='Density'>

# %% [markdown]
# Inference: viral load follows Normal distribution.

# %%
# Finding out the means for both the groups
df.groupby("sex")["viral load"].mean()
# Out:
# sex
# female     9.968298
# male      10.032440
# Name: viral load, dtype: float64

# %%
# separating the data for treatment group and control group.

df_male = df[df["sex"] == "male"]
df_female = df[df["sex"] == "female"]

# %%
df_male["viral load"].mean() - df_female["viral load"].mean()
# Out:
# 0.06414199020253086

# %%
stats.ttest_ind(df_male["viral load"], df_female["viral load"], alternative="less")
# Out:
# Ttest_indResult(statistic=0.5660752690218366, pvalue=0.7142753730121758)

# %% [markdown]
# Here pvalue>0.05, that difference of ~viral load=0.06 is not that significant enough to say that there is a huge difference between viral loads in male and female. So we are keeping our Null Hypothesis(ho) as it is.
#
# Lets pick the t-critical values by the t-distribution table.\
# We are going with Two sample two-sided t-test.\
# From this table, since sample size is more than 1,000, z-stats for 0.05 Confidence is ~1.64.
# Therefore tcritical = 1.64.\
# And tstats = 0.566, which is lesser than tcritical.\
# Therefore we accept the Null Hypothesis as it is.
#
# **Therefore, viral load of females == viral load of males.**

# %% [markdown]
# **2.c. Is the proportion of smoking significantly different across different regions?**
#
# Let,\
# ho: Proportion of smoking people is same across different regions\
# ha: Proportion of smoking people is different across different regions
#
# **Chi-square Test**

# %%
ctab = pd.crosstab(df['smoker'], df['region'])
ctab
# Out:
# region  northeast  northwest  southeast  southwest
# smoker
# no            256        267        267        265
# yes            39         38         35         26

# %%
from scipy.stats import chi2_contingency

# %%
stat, p, dof, expected = chi2_contingency(ctab)

# %%
print("Chi-square stat:",stat)
print("pvalue :",p)
# Out:
# Chi-square stat: 2.99680663546149
# pvalue : 0.39211779235957156

# %% [markdown]
# dof = (r-1)*(c-1) = 3\
# alpha = 0.05(for 95% Confidence)\
# chi-stats = 2.9968\
# See the Chi-square distribution table to know the chi-crit.\
# chi-crit = 7.815\
# chi-crit > chi-stats and pvalue>0.05, therefore we keep our Null hypothesis.
#
# **Therefore, there is relationship btw weather and season ie weather and season are dependent on each other.**

# %% [markdown]
# **2.d. Is the mean viral load of women with 0 Severity level , 1 Severity level, and 2 Severity level the same? Explain your answer with statistical evidence**
#
# Let,\
# ho: mean viral load of women with 0 Severity level , 1 Severity level, and 2 Severity level the same\
# ha: mean viral load of women with 0 Severity level , 1 Severity level, and 2 Severity level the different
#
# **One way Anova**

# %%
df.sex.value_counts()
# Out:
# female    611
# male      582
# Name: sex, dtype: int64

# %%
df.groupby('sex').agg({'viral load':'mean'}).reset_index(drop=True)
df_female = df[df["sex"]=='female']

# %%
# Let's not sample as we have only ~1000 datapoints.
female_severity_0 = df_female[df_female["severity level"]==0]["viral load"].sample(n=100)
female_severity_1 = df_female[df_female["severity level"]==1]["viral load"].sample(n=100)
female_severity_2 = df_female[df_female["severity level"]==2]["viral load"].sample(n=100)

female_severity_0 = female_severity_0.reset_index(drop=True)
female_severity_1 = female_severity_1.reset_index(drop=True)
female_severity_2 = female_severity_2.reset_index(drop=True)

dataset = pd.DataFrame({"0":female_severity_0, "1":female_severity_1, "2":female_severity_2})
dataset
# Out:
#         0      1      2
# 0    9.03  10.78  10.92
# 1    9.33  10.23  10.61
# 2    8.87  10.26  10.53
# 3   13.78   7.28   7.87
# 4    6.93   9.35  11.40
# ..    ...    ...    ...
# 95   8.23   8.03  11.21
# 96  10.41   7.25   8.60
# 97   7.38   5.60  11.91
# 98   9.53   6.60   8.87
# 99   6.84   9.13   7.79
#
# [100 rows x 3 columns]

# %%
dataset.isna().sum()
# Out:
# 0    0
# 1    0
# 2    0
# dtype: int64

# %%
dataset['0'].mean()
# Out:
# 9.978100000000001

# %%
dataset['1'].mean()
# Out:
# 9.832899999999997

# %%
dataset['2'].mean()
# Out:
# 10.0768

# %%
f, pval = stats.f_oneway(dataset["0"], dataset["1"], dataset["2"])
print(f, pval)
# Out:
# 0.3939396325870224 0.6747466210093129

# %% [markdown]
# Inference: Since pvalue>0.05, we keep our Null hypothesis as it is.
#
# **Therefore, mean viral load of women with 0 Severity level , 1 Severity level, and 2 Severity level the same**
